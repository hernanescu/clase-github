# %% [markdown]
# # Git: qué es y para qué sirve
# - Git es un sistema gratuito y abierto de control de versiones.
# - Todos los developers interactúan con esto de alguna u otra manera.
#
# #### ¿Control de versión? ¿Con qué se come?
# - Básicamente es una forma que tenemos para trackear nuestros cambios en el código.
# - La idea es guardar versiones iniciales en Git, y a medida que vamos progresando podemos ir guardando distintas versiones. A medida que el código evoluciona, podemos ver todos los cambios que hicimos.
# - Esto es excesivamente importante para entender qué fue pasando, buscar versiones anteriores en caso de que algo falle, etc.

# %% [markdown]
# #### Algunos términos
# - Directorio: Una carpeta.
# - Terminal o Command Line: la interfaz para comandos de texto.
# - CLI: Command Line Interface.
# - Repositorio: Suele referirse a un repositorio de Git. Una carpeta donde está todo el proyecto.
# - GitHub: Git es la herramienta con la que hacemos tod oesto, y GitHub es un sitio web donde hosteás tus repositorios online y te permite no sólo hacer un portfolio sino también trabajar de manera colaborativa (ya vamos a ver eso!).
#
#
# #### Algunos comandos de Git
# - clone: Traer un repositorio que está hosteado en otro lugar (como GitHub) a tu entorno local (mayormente tu computadora).
# - add: Trackear archivos y cambios en Git.
# - commit: Guardar los archivos modificados. "Commiteaste el cambio?".
# - push: Subir los commits de git a un repositorio remoto, como GitHub. El opuesto de pull.
# - pull: Bajar los cambios del repo remoto a la máquina local. El opuesto de push.

# %% [markdown]
# ## Setup en GitHub

# %% [markdown]
# Entran a github.com y se hacen una cuenta gratuita.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Por ahora dejamos todo como viene.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Vamos a mostrar qué es eso de los cambios, creando el primer archivo: el README.md, un clásico de este tipo de proyectos. Clickeamos en Crear un archivo nuevo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ups, me olvidé el título! Veamos cómo editar:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora dice Update README.md. Para ver todos los cambios, podés clickear en Commmits:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Carpeta oculta: .git. List all: mostrar absolutamente todo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Git status muestra todos los archivos que fueron actualizados, creados o borrados, pero que todavía no se guardaron en un commit.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Git no sabe del archivo:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# En el panel pueden ver que hay una U (untracked) y una M (modified). Hay que decirle a git que los trackee.
#
# Pequeño truco: el "." indica "todo lo que está en esta posición".

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Nos faltó loguear en Git:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora tenemos que hacer un push! Pero hay antes otro tema con la seguridad. La idea es probarle a GitHub que la cuenta es tuya, y esto se hace con SSH Keys.

# %% [markdown]
# El default es en la carpeta .ssh y el nombre id_rsa. Como ya tengo una, le pongo otro nombre.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - paecis.pub es la llave que se sube a la interfaz de GitHub (pub de público).
# - La que no tiene el .pub es la llave privada, que es la que NO SE TIENE QUE SUBIR NUNCA JAMÁS A NINGÚN LUGAR NI COMPARTIR CON NADIE. Las mayúsculas son necesarias!
#
# **¿Cómo funciona?**
#
# Básicamente cada vez que querés pushear o publicar, usás tu private key para mostrarle que vos sos quien generó la public key. Es un método de criptografía matemática (no me pregunten, soy sólo un sociólogo).

# %%
# !cat clase-github/paecis.pub
# Out:
# ssh-rsa ... hernanescu@gmail.com

# %% [markdown]
# Con esto listo, vamos a los Settings de Github. Copiamos y pegamos la clave:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Agregué la notebook en la que venimos trabajando.
# - Modifiqué un poquito el código del excusator.

# %% [markdown]
# ### Git Push
# Para subir el código, tenemos que indicarle de dónde a dónde queremos pushear. Normalmente origin designa el origen (dónde está el repo que querés pushear) y luego la rama, que en nuestro caso es "main". Ya vamos a hablar de la ramas :)
#
# Paréntesis: antes se lo llamaba "master", pero se le cambió la nomenclatura por ciertas connotaciones.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Subir código local a un repo nuevo
# *AKA: "Cómo subo el tp final?"*
#
# Hasta ahora vimos cómo clonar algo que ya estaba, pero si queremos subir algo en un repo nuevo?
#
# A modo ilustrativo, voy a crear una carpeta llamada TP Final y subirlo a un repo nuevo. Veamos cómo:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Si miran la consola, primero se ve que en clase-github hay un repo de Git.
# - Pero la carpeta anterior a esa (clase-git) no tiene nada "fatal!".
# - Lo mismo se verifica en la carpeta que creé, repo-tp-final.
# - Le agregué un readme ilustrativo, nomás para subirle algo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Iniciamos el repo. Por alguna razón lo inició con el nombre "master" y no "main".
# - Agregamos cosas.
# - Commiteamos: con el segundo -m se le puede dar una descripción extendida (ya vemos donde queda)
# - Tratamos de pushear a main: no se puede, porque no existe (la rama que creó es master).
# - Pero cuando subimos, Git dice que no tiene idea de a dónde pushear porque no está conectado a nada.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Creamos un nuevo repo, y abajo de todo básicamente te dice qué tenés que hacer, pero expliquémoslo un poquito :)
# - remote quiere decir "algún lugar que no es el entorno local donde estoy ahora". O sea, no-mi-compu.
# - Para emprolijar, creamos una branch llamada main (cosa de trabajar siempre en esa).
# - Subimos todo con git push.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Y listo! Sólo a efectos ilustrativos, dentro del código subido y dentro del commit, podemos ver dónde está la descripción extendida que había escrito.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Agregando el -u seteamos el upstream: la dirección por default. Haciendo esto, sólo con git push ya lo sube.

# %% [markdown]
# ### Branch
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Acá empieza el auténtico desafío. Las ramas te permiten trabajar de forma aislada sin afectar el desarollo principal. Puede haber un branch por persona, un branch por feature nuevo, etc. La idea es dejar siempre al resguardo el código productivo.
#
# ![image.png](attachment:image.png)
